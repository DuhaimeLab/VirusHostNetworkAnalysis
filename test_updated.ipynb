# %%
# %reload_ext autoreload
# %autoreload 2
from VirusHostNetworkAnalysis.prediction_matrix import PredictionMatrix
# print directory
matrix_1 = PredictionMatrix("Sample_Input/Aug4_predictions.tsv")
matrix_1.make_rectangular_matrix('prob')
matrix_1.plot_heatmap('prob')
print(matrix_1.virus_host_array)
# Out:
# updated
# Unique viruses and hosts found
# updated
# Matrix initialized
# Matrix filled
# rows sorted
# columns sorted
# [[8.82175515e-01 9.97079488e-01 9.97079488e-01 ... 9.98669693e-01
#   9.97446263e-01 9.91821674e-01]
#  [9.99880047e-01 9.99742445e-01 9.99742445e-01 ... 9.81784786e-01
#   9.92762618e-01 9.20669715e-01]
#  [9.19073270e-01 9.81786371e-01 9.81786371e-01 ... 9.95659536e-01
#   7.56150734e-01 9.90321880e-01]
#  ...
#  [1.16848638e-03 4.73050176e-03 1.87476427e-02 ... 4.52123937e-05
#   7.25268636e-04 1.76201358e-04]
#  [1.60757372e-02 1.78714831e-03 2.79359971e-03 ... 3.45910043e-04
#   1.00588155e-04 2.70780184e-04]
#  [9.89631890e-04 8.31987711e-03 6.93987643e-03 ... 1.76201358e-04
#   7.75007309e-05 3.96523201e-05]]
